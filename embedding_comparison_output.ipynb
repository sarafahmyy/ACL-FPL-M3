# %% [markdown]
# # Embedding Model Comparison Results
#
# ## Summary
#
# | Model | Questions Processed | Total Results |
# |-------|--------------------:|--------------:|
# | text-embedding-3-large | 13 | 48 |
# | text-embedding-3-small | 13 | 46 |
#
# ---
#
# ## Question 1: who is cr7
#
# ### Model: text-embedding-3-large
#
# | Rank | Player | Position | confidence |
# |-----:|--------|----------|------:|
# | 1 | Cristiano Ronaldo dos Santos Aveiro | FWD | 0.7490 |
# | 2 | Bernardo Mota Veiga de Carvalho e Silva | MID | 0.6604 |
# | 3 | Bruno Miguel Borges Fernandes | MID | 0.6576 |
# | 4 | João Cancelo | DEF | 0.6541 |
#
# ### Model: text-embedding-3-small
#
# | Rank | Player | Position | confidence |
# |-----:|--------|----------|------:|
# | 1 | Cristiano Ronaldo dos Santos Aveiro | FWD | 0.7278 |
# | 2 | Cristian Romero | DEF | 0.6824 |
# | 3 | Douglas Luiz Soares de Paulo | MID | 0.6822 |
#
# ---
#
# ## Question 2: tell me forwards from the gunners
#
# ### Model: text-embedding-3-large
#
# | Rank | Player | Position | confidence |
# |-----:|--------|----------|------:|
# | 1 | Folarin Balogun | FWD | 0.6941 |
# | 2 | Gabriel Martinelli Silva | None | 0.6773 |
# | 3 | Gabriel Teodoro Martinelli Silva | None | 0.6755 |
# | 4 | Pierre-Emerick Aubameyang | FWD | 0.6753 |
#
# ### Model: text-embedding-3-small
#
# | Rank | Player | Position | confidence |
# |-----:|--------|----------|------:|
# | 1 | Theo Walcott | None | 0.6879 |
# | 2 | Ainsley Maitland-Niles | None | 0.6807 |
# | 3 | Olivier Giroud | FWD | 0.6806 |
#
# ---
#
# ## Question 3: Who is Momo Salah?
#
# ### Model: text-embedding-3-large
#
# | Rank | Player | Position | confidence |
# |-----:|--------|----------|------:|
# | 1 | Mohamed Salah | MID | 0.7264 |
# | 2 | Salah-Eddine Oulad M'hand | MID | 0.7047 |
# | 3 | Mohammed Salisu | DEF | 0.6799 |
#
# ### Model: text-embedding-3-small
#
# | Rank | Player | Position | confidence |
# |-----:|--------|----------|------:|
# | 1 | Mohamed Salah | MID | 0.7331 |
# | 2 | Salah-Eddine Oulad M'hand | MID | 0.7273 |
# | 3 | Mohammed Salisu | DEF | 0.6866 |
#
# ---
#
# ## Question 4: Top forwards in 2022/23 season
#
# ### Model: text-embedding-3-large
#
# | Rank | Player | Position | confidence |
# |-----:|--------|----------|------:|
# | 1 | Erling Haaland | FWD | 0.7873 |
# | 2 | Kai Havertz | None | 0.7707 |
# | 3 | Aleksandar Mitrović | FWD | 0.7699 |
# | 4 | Phil Foden | None | 0.7665 |
#
# ### Model: text-embedding-3-small
#
# | Rank | Player | Position | confidence |
# |-----:|--------|----------|------:|
# | 1 | Sékou Mara | FWD | 0.7415 |
# | 2 | Alexandre Lacazette | FWD | 0.7414 |
# | 3 | Marcus Forss | FWD | 0.7405 |
# | 4 | Gabriel Fernando de Jesus | FWD | 0.7396 |
#
# ---
#
# ## Question 5: Show me stats and goals for kdb in 2022-23
#
# ### Model: text-embedding-3-large
#
# | Rank | Player | Position | confidence |
# |-----:|--------|----------|------:|
# | 1 | Kevin De Bruyne | MID | 0.8154 |
# | 2 | Kai Havertz | MID | 0.7819 |
# | 3 | Kepa Arrizabalaga | GK | 0.7761 |
#
# ### Model: text-embedding-3-small
#
# | Rank | Player | Position | confidence |
# |-----:|--------|----------|------:|
# | 1 | Kobbie Mainoo | MID | 0.7527 |
# | 2 | Kiernan Dewsbury-Hall | MID | 0.7486 |
# | 3 | Kadan Young | MID | 0.7456 |
# | 4 | Kaden Rodney | MID | 0.7444 |
#
# ---
#
# ## Question 6: How many points did Haaland get in GW 3 2022-23?
#
# ### Model: text-embedding-3-large
#
# | Rank | Player | Position | confidence |
# |-----:|--------|----------|------:|
# | 1 | Erling Haaland | FWD | 0.8522 |
# | 2 | Hee-Chan Hwang | FWD | 0.7936 |
# | 3 | Jadon Sancho | MID | 0.7824 |
# | 4 | Sam Greenwood | FWD | 0.7716 |
#
# ### Model: text-embedding-3-small
#
# | Rank | Player | Position | confidence |
# |-----:|--------|----------|------:|
# | 1 | Erling Haaland | FWD | 0.8441 |
# | 2 | Andreas Hoelgebaum Pereira | None | 0.7653 |
# | 3 | Hwang Hee-chan | None | 0.7578 |
# | 4 | Wout Weghorst | FWD | 0.7540 |
#
# ---
#
# ## Question 7: Tell me about spurs
#
# ### Model: text-embedding-3-large
#
# | Rank | Player | Position | confidence |
# |-----:|--------|----------|------:|
# | 1 | Harry Winks | MID | 0.6849 |
# | 2 | Oliver Skipp | MID | 0.6849 |
# | 3 | Tanguy Ndombele | MID | 0.6815 |
#
# ### Model: text-embedding-3-small
#
# | Rank | Player | Position | confidence |
# |-----:|--------|----------|------:|
# | 1 | Harry Winks | MID | 0.6904 |
# | 2 | Dele Alli | MID | 0.6842 |
# | 3 | Toby Alderweireld | DEF | 0.6719 |
# | 4 | Djed Spence | DEF | 0.6711 |
#
# ---
#
# ## Question 8: give me 4 midfielders from arsenal
#
# ### Model: text-embedding-3-large
#
# | Rank | Player | Position | confidence |
# |-----:|--------|----------|------:|
# | 1 | Gabriel Teodoro Martinelli Silva | MID | 0.6941 |
# | 2 | Gabriel Martinelli Silva | MID | 0.6885 |
# | 3 | Granit Xhaka | MID | 0.6865 |
# | 4 | Thomas Partey | MID | 0.6862 |
#
# ### Model: text-embedding-3-small
#
# | Rank | Player | Position | confidence |
# |-----:|--------|----------|------:|
# | 1 | Gabriel Martinelli Silva | MID | 0.6955 |
# | 2 | Theo Walcott | MID | 0.6938 |
# | 3 | Gabriel Teodoro Martinelli Silva | MID | 0.6873 |
# | 4 | Bukayo Saka | MID | 0.6863 |
#
# ---
#
# ## Question 9: how did the egyption king perform
#
# ### Model: text-embedding-3-large
#
# | Rank | Player | Position | confidence |
# |-----:|--------|----------|------:|
# | 1 | Mohamed Elneny | MID | 0.6336 |
# | 2 | Mohamed Naser El Sayed Elneny | MID | 0.6303 |
# | 3 | Mahmoud Ahmed Ibrahim Hassan | MID | 0.6222 |
# | 4 | Enock Mwepu | MID | 0.6091 |
#
# ### Model: text-embedding-3-small
#
# | Rank | Player | Position | confidence |
# |-----:|--------|----------|------:|
# | 1 | Mohamed Naser El Sayed Elneny | MID | 0.6517 |
# | 2 | Mohamed Elneny | MID | 0.6421 |
# | 3 | Mohamed Salah | MID | 0.6084 |
# | 4 | Salah-Eddine Oulad M'hand | MID | 0.6078 |
#
# ---
#
# ## Question 10: Show me stats and goals for midfielders in 2022-23
#
# ### Model: text-embedding-3-large
#
# | Rank | Player | Position | confidence |
# |-----:|--------|----------|------:|
# | 1 | Kevin De Bruyne | MID | 0.7872 |
# | 2 | Paul Pogba | MID | 0.7856 |
# | 3 | Bernardo Veiga de Carvalho e Silva | MID | 0.7847 |
# | 4 | Andreas Hoelgebaum Pereira | MID | 0.7829 |
#
# ### Model: text-embedding-3-small
#
# | Rank | Player | Position | confidence |
# |-----:|--------|----------|------:|
# | 1 | Mateus Cardoso Lemos Martins | MID | 0.7781 |
# | 2 | Bernardo Mota Veiga de Carvalho e Silva | MID | 0.7744 |
# | 3 | Lucas Rodrigues Moura da Silva | MID | 0.7734 |
# | 4 | Fábio Freitas Gouveia Carvalho | MID | 0.7683 |
#
# ---
#
# ## Question 11: who is halaand?
#
# ### Model: text-embedding-3-large
#
# | Rank | Player | Position | confidence |
# |-----:|--------|----------|------:|
# | 1 | Hee-Chan Hwang | FWD | 0.6958 |
# | 2 | Halil Dervişoğlu | FWD | 0.6930 |
# | 3 | Mathias Normann | MID | 0.6890 |
# | 4 | Martin Ødegaard | MID | 0.6868 |
#
# ### Model: text-embedding-3-small
#
# | Rank | Player | Position | confidence |
# |-----:|--------|----------|------:|
# | 1 | Erling Haaland | FWD | 0.6430 |
# | 2 | Halil Dervişoğlu | FWD | 0.6172 |
# | 3 | Pierre-Emile Højbjerg | MID | 0.6158 |
#
# ---
#
# ## Question 12: compare between mohamed salah and harry kane performance in 2021-22 season
#
# ### Model: text-embedding-3-large
#
# | Rank | Player | Position | confidence |
# |-----:|--------|----------|------:|
# | 1 | Harry Kane | FWD | 0.7872 |
# | 2 | Mohamed Salah | MID | 0.7791 |
# | 3 | Riyad Mahrez | MID | 0.7243 |
#
# ### Model: text-embedding-3-small
#
# | Rank | Player | Position | confidence |
# |-----:|--------|----------|------:|
# | 1 | Harry Kane | FWD | 0.7798 |
# | 2 | Mohamed Salah | MID | 0.7796 |
# | 3 | Salah-Eddine Oulad M'hand | MID | 0.7536 |
#
# ---
#
# ## Question 13: ايه هي ارقام صارؤخ ماضيلرا في الموسم اللي فات
#
# ### Model: text-embedding-3-large
#
# | Rank | Player | Position | confidence |
# |-----:|--------|----------|------:|
# | 1 | Mohamed Dräger | DEF | 0.6512 |
# | 2 | Mohamed Salah | MID | 0.6476 |
# | 3 | Salah-Eddine Oulad M'hand | MID | 0.6454 |
# | 4 | Sékou Mara | FWD | 0.6421 |
#
# ### Model: text-embedding-3-small
#
# | Rank | Player | Position | confidence |
# |-----:|--------|----------|------:|
# | 1 | Naouirou Ahamada | MID | 0.6846 |
# | 2 | Anwar El Ghazi | MID | 0.6810 |
# | 3 | Hakim Ziyech | MID | 0.6805 |
#
# ---
#
# ## Detailed Results by Model
#
# ### text-embedding-3-large
#
# *Question:* who is cr7
#
# | Rank | Player | Position | confidence |
# |-----:|--------|----------|------:|
# | 1 | Cristiano Ronaldo dos Santos Aveiro | FWD | 0.7490 |
# | 2 | Bernardo Mota Veiga de Carvalho e Silva | MID | 0.6604 |
# | 3 | Bruno Miguel Borges Fernandes | MID | 0.6576 |
# | 4 | João Cancelo | DEF | 0.6541 |
#
# *Question:* tell me forwards from the gunners
#
# | Rank | Player | Position | confidence |
# |-----:|--------|----------|------:|
# | 1 | Folarin Balogun | FWD | 0.6941 |
# | 2 | Gabriel Martinelli Silva | None | 0.6773 |
# | 3 | Gabriel Teodoro Martinelli Silva | None | 0.6755 |
# | 4 | Pierre-Emerick Aubameyang | FWD | 0.6753 |
#
# *Question:* Who is Momo Salah?
#
# | Rank | Player | Position | confidence |
# |-----:|--------|----------|------:|
# | 1 | Mohamed Salah | MID | 0.7264 |
# | 2 | Salah-Eddine Oulad M'hand | MID | 0.7047 |
# | 3 | Mohammed Salisu | DEF | 0.6799 |
#
# *Question:* Top forwards in 2022/23 season
#
# | Rank | Player | Position | confidence |
# |-----:|--------|----------|------:|
# | 1 | Erling Haaland | FWD | 0.7873 |
# | 2 | Kai Havertz | None | 0.7707 |
# | 3 | Aleksandar Mitrović | FWD | 0.7699 |
# | 4 | Phil Foden | None | 0.7665 |
#
# *Question:* Show me stats and goals for kdb in 2022-23
#
# | Rank | Player | Position | confidence |
# |-----:|--------|----------|------:|
# | 1 | Kevin De Bruyne | MID | 0.8154 |
# | 2 | Kai Havertz | MID | 0.7819 |
# | 3 | Kepa Arrizabalaga | GK | 0.7761 |
#
# *Question:* How many points did Haaland get in GW 3 2022-23?
#
# | Rank | Player | Position | confidence |
# |-----:|--------|----------|------:|
# | 1 | Erling Haaland | FWD | 0.8522 |
# | 2 | Hee-Chan Hwang | FWD | 0.7936 |
# | 3 | Jadon Sancho | MID | 0.7824 |
# | 4 | Sam Greenwood | FWD | 0.7716 |
#
# *Question:* Tell me about spurs
#
# | Rank | Player | Position | confidence |
# |-----:|--------|----------|------:|
# | 1 | Harry Winks | MID | 0.6849 |
# | 2 | Oliver Skipp | MID | 0.6849 |
# | 3 | Tanguy Ndombele | MID | 0.6815 |
#
# *Question:* give me 4 midfielders from arsenal
#
# | Rank | Player | Position | confidence |
# |-----:|--------|----------|------:|
# | 1 | Gabriel Teodoro Martinelli Silva | MID | 0.6941 |
# | 2 | Gabriel Martinelli Silva | MID | 0.6885 |
# | 3 | Granit Xhaka | MID | 0.6865 |
# | 4 | Thomas Partey | MID | 0.6862 |
#
# *Question:* how did the egyption king perform
#
# | Rank | Player | Position | confidence |
# |-----:|--------|----------|------:|
# | 1 | Mohamed Elneny | MID | 0.6336 |
# | 2 | Mohamed Naser El Sayed Elneny | MID | 0.6303 |
# | 3 | Mahmoud Ahmed Ibrahim Hassan | MID | 0.6222 |
# | 4 | Enock Mwepu | MID | 0.6091 |
#
# *Question:* Show me stats and goals for midfielders in 2022-23
#
# | Rank | Player | Position | confidence |
# |-----:|--------|----------|------:|
# | 1 | Kevin De Bruyne | MID | 0.7872 |
# | 2 | Paul Pogba | MID | 0.7856 |
# | 3 | Bernardo Veiga de Carvalho e Silva | MID | 0.7847 |
# | 4 | Andreas Hoelgebaum Pereira | MID | 0.7829 |
#
# *Question:* who is halaand?
#
# | Rank | Player | Position | confidence |
# |-----:|--------|----------|------:|
# | 1 | Hee-Chan Hwang | FWD | 0.6958 |
# | 2 | Halil Dervişoğlu | FWD | 0.6930 |
# | 3 | Mathias Normann | MID | 0.6890 |
# | 4 | Martin Ødegaard | MID | 0.6868 |
#
# *Question:* compare between mohamed salah and harry kane performance in 2021-22 season
#
# | Rank | Player | Position | confidence |
# |-----:|--------|----------|------:|
# | 1 | Harry Kane | FWD | 0.7872 |
# | 2 | Mohamed Salah | MID | 0.7791 |
# | 3 | Riyad Mahrez | MID | 0.7243 |
#
# *Question:* ايه هي ارقام صارؤخ ماضيلرا في الموسم اللي فات
#
# | Rank | Player | Position | confidence |
# |-----:|--------|----------|------:|
# | 1 | Mohamed Dräger | DEF | 0.6512 |
# | 2 | Mohamed Salah | MID | 0.6476 |
# | 3 | Salah-Eddine Oulad M'hand | MID | 0.6454 |
# | 4 | Sékou Mara | FWD | 0.6421 |
#
# ---
#
# ### text-embedding-3-small
#
# *Question:* who is cr7
#
# | Rank | Player | Position | confidence |
# |-----:|--------|----------|------:|
# | 1 | Cristiano Ronaldo dos Santos Aveiro | FWD | 0.7278 |
# | 2 | Cristian Romero | DEF | 0.6824 |
# | 3 | Douglas Luiz Soares de Paulo | MID | 0.6822 |
#
# *Question:* tell me forwards from the gunners
#
# | Rank | Player | Position | confidence |
# |-----:|--------|----------|------:|
# | 1 | Theo Walcott | None | 0.6879 |
# | 2 | Ainsley Maitland-Niles | None | 0.6807 |
# | 3 | Olivier Giroud | FWD | 0.6806 |
#
# *Question:* Who is Momo Salah?
#
# | Rank | Player | Position | confidence |
# |-----:|--------|----------|------:|
# | 1 | Mohamed Salah | MID | 0.7331 |
# | 2 | Salah-Eddine Oulad M'hand | MID | 0.7273 |
# | 3 | Mohammed Salisu | DEF | 0.6866 |
#
# *Question:* Top forwards in 2022/23 season
#
# | Rank | Player | Position | confidence |
# |-----:|--------|----------|------:|
# | 1 | Sékou Mara | FWD | 0.7415 |
# | 2 | Alexandre Lacazette | FWD | 0.7414 |
# | 3 | Marcus Forss | FWD | 0.7405 |
# | 4 | Gabriel Fernando de Jesus | FWD | 0.7396 |
#
# *Question:* Show me stats and goals for kdb in 2022-23
#
# | Rank | Player | Position | confidence |
# |-----:|--------|----------|------:|
# | 1 | Kobbie Mainoo | MID | 0.7527 |
# | 2 | Kiernan Dewsbury-Hall | MID | 0.7486 |
# | 3 | Kadan Young | MID | 0.7456 |
# | 4 | Kaden Rodney | MID | 0.7444 |
#
# *Question:* How many points did Haaland get in GW 3 2022-23?
#
# | Rank | Player | Position | confidence |
# |-----:|--------|----------|------:|
# | 1 | Erling Haaland | FWD | 0.8441 |
# | 2 | Andreas Hoelgebaum Pereira | None | 0.7653 |
# | 3 | Hwang Hee-chan | None | 0.7578 |
# | 4 | Wout Weghorst | FWD | 0.7540 |
#
# *Question:* Tell me about spurs
#
# | Rank | Player | Position | confidence |
# |-----:|--------|----------|------:|
# | 1 | Harry Winks | MID | 0.6904 |
# | 2 | Dele Alli | MID | 0.6842 |
# | 3 | Toby Alderweireld | DEF | 0.6719 |
# | 4 | Djed Spence | DEF | 0.6711 |
#
# *Question:* give me 4 midfielders from arsenal
#
# | Rank | Player | Position | confidence |
# |-----:|--------|----------|------:|
# | 1 | Gabriel Martinelli Silva | MID | 0.6955 |
# | 2 | Theo Walcott | MID | 0.6938 |
# | 3 | Gabriel Teodoro Martinelli Silva | MID | 0.6873 |
# | 4 | Bukayo Saka | MID | 0.6863 |
#
# *Question:* how did the egyption king perform
#
# | Rank | Player | Position | confidence |
# |-----:|--------|----------|------:|
# | 1 | Mohamed Naser El Sayed Elneny | MID | 0.6517 |
# | 2 | Mohamed Elneny | MID | 0.6421 |
# | 3 | Mohamed Salah | MID | 0.6084 |
# | 4 | Salah-Eddine Oulad M'hand | MID | 0.6078 |
#
# *Question:* Show me stats and goals for midfielders in 2022-23
#
# | Rank | Player | Position | confidence |
# |-----:|--------|----------|------:|
# | 1 | Mateus Cardoso Lemos Martins | MID | 0.7781 |
# | 2 | Bernardo Mota Veiga de Carvalho e Silva | MID | 0.7744 |
# | 3 | Lucas Rodrigues Moura da Silva | MID | 0.7734 |
# | 4 | Fábio Freitas Gouveia Carvalho | MID | 0.7683 |
#
# *Question:* who is halaand?
#
# | Rank | Player | Position | confidence |
# |-----:|--------|----------|------:|
# | 1 | Erling Haaland | FWD | 0.6430 |
# | 2 | Halil Dervişoğlu | FWD | 0.6172 |
# | 3 | Pierre-Emile Højbjerg | MID | 0.6158 |
#
# *Question:* compare between mohamed salah and harry kane performance in 2021-22 season
#
# | Rank | Player | Position | confidence |
# |-----:|--------|----------|------:|
# | 1 | Harry Kane | FWD | 0.7798 |
# | 2 | Mohamed Salah | MID | 0.7796 |
# | 3 | Salah-Eddine Oulad M'hand | MID | 0.7536 |
#
# *Question:* ايه هي ارقام صارؤخ ماضيلرا في الموسم اللي فات
#
# | Rank | Player | Position | confidence |
# |-----:|--------|----------|------:|
# | 1 | Naouirou Ahamada | MID | 0.6846 |
# | 2 | Anwar El Ghazi | MID | 0.6810 |
# | 3 | Hakim Ziyech | MID | 0.6805 |
#
# ---
